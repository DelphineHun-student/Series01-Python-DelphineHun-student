# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
data = np.loadtxt('data/ECGu.txt') # Load the ECG data from a text file
print(data)
print(data.shape) # (number of rows, number of columns)
# Out:
# [[ 0.000e+00  0.000e+00  0.000e+00 -2.750e+02 -1.190e+02 -1.190e+02]
#  [ 1.000e-03  1.000e-03  1.000e-03 -2.750e+02 -1.190e+02 -1.190e+02]
#  [ 2.000e-03  2.000e-03  2.000e-03 -2.750e+02 -1.180e+02 -1.210e+02]
#  ...
#  [ 6.497e+00  6.497e+00  6.497e+00 -4.000e+00 -8.300e+01  2.100e+01]
#  [ 6.498e+00  6.498e+00  6.498e+00 -9.000e+00 -8.800e+01  3.100e+01]
#  [ 6.499e+00  6.499e+00  6.499e+00 -1.600e+01 -9.600e+01  3.300e+01]]
# (6500, 6)

# %% [markdown]
# ## Conversion to mV and adding time (in sec)

# %%
ecg_mv = data * 1.024 # Convert to mV

# %% [markdown]
# # ECG plot

# %%
# Charger les données (suppose 4 colonnes : temps + 3 amplitudes)
data = np.loadtxt('data/ECGu.txt', skiprows=1)  
fig, axs = plt.subplots(3, 1, figsize=(10, 8), sharex=True)

time = data[:, 0]
amplitude1 = data[:, 3]
amplitude2 = data[:, 4]
amplitude3 = data[:, 5]

axs[0].plot(time, amplitude1)
axs[1].plot(time, amplitude2)
axs[2].plot(time, amplitude3)
plt.figure(figsize=(10, 5))

plt.tight_layout
plt.show()

# %%
plt.figure(figsize=(10, 5))
for i in range(amplitudes.shape[3]):
    plt.plot(time, amplitudes[:, i], label=f'Amplitude {i+1}')
